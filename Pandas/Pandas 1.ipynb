# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.6

# %% [markdown]
# ## Application of Pandas
# ##### - Easy to handle
# ##### - Size mutable
# ##### - Automatic and explicit data alignment
# ##### - Powerfull and flexiable
# ##### - Inteligent label

# %%
student={
    'id':["S001","S002","S003","S004"],
    'name':["abc1","abc2","abc3","abc4"],
    'age:':[21,23,20,24]
}
df=pd.DataFrame(student)
df
df.shape
df.size
df.columns
# Out:
# Index(['id', 'name', 'age:'], dtype='str')
